# %%
# Extract data tables to update PROD

from worker.database import connect
import polars as pl

# %%
with connect() as session:
    df_instruments = pl.read_database("SELECT * FROM instruments", session)
    df_portfolios = pl.read_database("SELECT * FROM portfolios", session)
    df_investments = pl.read_database("SELECT * FROM investments", session)
    df_measures = pl.read_database("SELECT * FROM measures", session)
    
    df_ptf_comp = pl.read_database("SELECT * FROM ptf_comp", session)
    df_ptf_values = pl.read_database("SELECT * FROM ptf_values", session)
    df_measures = pl.read_database("SELECT * FROM measures", session)
